# %%
print('hello')
# Out:
# hello

# %%
# !ls
# Out:
# 01-Hello.cu  sample_data

# %%
# !nvidia-smi
# Out:
# Sat Sep 23 02:13:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Biên dịch chương trình

# %%
# !nvcc 01-Hello.cu

# %%
# !nvcc -arch=sm_75 01-Hello.cu

# %%
# !ls
# Out:
# 01-Hello.cu  a.out  sample_data

# %%
# !./a.out
# Out:
# Hello from CPU!
# **********GPU info**********
# Name: Tesla T4
# Compute capability: 7.5
# GMEM: 15835398144 byte
# ****************************
# Hello from GPU, threadId 0!
# Hello from GPU, threadId 1!
# Hello from GPU, threadId 2!
# Hello from GPU, threadId 3!
# Hello from GPU, threadId 4!
# Hello from GPU, threadId 5!
# Hello from GPU, threadId 6!
# Hello from GPU, threadId 7!
# Hello from GPU, threadId 8!
# Hello from GPU, threadId 9!
# Hello from GPU, threadId 10!
# Hello from GPU, threadId 11!
# Hello from GPU, threadId 12!
# Hello from GPU, threadId 13!
# Hello from GPU, threadId 14!
# Hello from GPU, threadId 15!
# Hello from GPU, threadId 16!
# Hello from GPU, threadId 17!
# Hello from GPU, threadId 18!
# Hello from GPU, threadId 19!
# Hello from GPU, threadId 20!
# Hello from GPU, threadId 21!
# Hello from GPU, threadId 22!
# Hello from GPU, threadId 23!
# Hello from GPU, threadId 24!
# Hello from GPU, threadId 25!
# Hello from GPU, threadId 26!
# ...
